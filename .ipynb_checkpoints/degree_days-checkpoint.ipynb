# %%
import numpy as np
import pandas as pd
from scipy.optimize import curve_fit
from scipy.integrate import quad
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
from scipy.optimize import curve_fit
from scipy.integrate import quad
import matplotlib.pyplot as plt

# Define the enhanced model function
def model(x, a, b, c, d, e, f):
    return a * x + b + c * np.exp(d * x) * np.cos(2 * np.pi * e * x + f)

# Load the data
data = np.loadtxt('result_CMIP6_ssp245.txt', skiprows=0, unpack=False)
header = ['id', 'month', 'Tair', 'snow', '0.01m', '0.08m', '0.13m', '0.24m', '0.38m', '0.53m', '0.67m']
df = pd.DataFrame(data, columns=header)
months = df['month'].values

# Prepare a figure for plotting
plt.figure(figsize=(12, 8))

# List of depths to plot
depths_to_plot = ['0.01m']  # Specify the depths you want to process

# Process each depth
for depth in depths_to_plot:
    temperatures = df[depth].values
    
    # Fit the enhanced model
    params, _ = curve_fit(model, months, temperatures, p0=[0.1, 25, 1, 0.01, 1/12, 0])
    
    # Generate data for the fitted curve
    x_fit = np.linspace(min(months), max(months), 1000)
    y_fit = model(x_fit, *params)
    
    # Define integrals for positive and negative parts
    def integrate_positive(start_month, end_month):
        def integrand(x):
            y = model(x, *params)
            return y if y > 0 else 0
        return quad(integrand, start_month, end_month)[0]

    def integrate_negative(start_month, end_month):
        def integrand(x):
            y = model(x, *params)
            return -y if y < 0 else 0
        return quad(integrand, start_month, end_month)[0]
    
    # Ensure the number of years is an integer
    num_months = int(max(months) - min(months))
    num_years = num_months // 12
    
    # Calculate and print yearly integrals
    for year in range(num_years):
        start_month = min(months) + year * 12
        end_month = start_month + 12
        
        integral_pos = integrate_positive(start_month, end_month)
        integral_neg = integrate_negative(start_month, end_month)
        
        print(f'Year {year + 1}:')
        print(f'  Integral of T(t) where T(t) > 0 ºC: {integral_pos}')
        print(f'  Integral of |T(t)| where T(t) < 0 ºC: {integral_neg}')
    
    # Handle any remaining months if they don't fit exactly into full years
    if (max(months) - min(months)) % 12 != 0:
        remaining_start = min(months) + num_years * 12
        remaining_end = max(months)
        
        integral_pos = integrate_positive(remaining_start, remaining_end)
        integral_neg = integrate_negative(remaining_start, remaining_end)
        
        print(f'Remaining Period:')
        print(f'  Integral of T(t) where T(t) > 0 ºC: {integral_pos}')
        print(f'  Integral of |T(t)| where T(t) < 0 ºC: {integral_neg}')
    
    # Plot the data and fitted curve
    plt.plot(months, temperatures, '-', label=f'Original Data ({depth})', alpha=0.7)
    plt.plot(x_fit, y_fit, '-', label=f'Fitted Curve ({depth})')

plt.xlabel('Month')
plt.ylabel('Temperature (ºC)')
plt.title('Monthly Temperature and Fitted Model at Different Depths')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Year 1:
#   Integral of T(t) where T(t) > 0 ºC: 14.591059702983916
#   Integral of |T(t)| where T(t) < 0 ºC: 21.294907563220534
# Year 2:
#   Integral of T(t) where T(t) > 0 ºC: 14.82414869210384
#   Integral of |T(t)| where T(t) < 0 ºC: 21.161520772668606
# Year 3:
#   Integral of T(t) where T(t) > 0 ºC: 15.058329024919072
#   Integral of |T(t)| where T(t) < 0 ºC: 21.029225623190417
# Year 4:
#   Integral of T(t) where T(t) > 0 ºC: 15.293592126511294
#   Integral of |T(t)| where T(t) < 0 ºC: 20.89801372583311
# Year 5:
#   Integral of T(t) where T(t) > 0 ºC: 15.529929971158504
#   Integral of |T(t)| where T(t) < 0 ºC: 20.767876957227244
# Year 6:
#   Integral of T(t) where T(t) > 0 ºC: 15.767333069648554
#   Integral of |T(t)| where T(t) < 0 ºC: 20.638805871043225
# Year 7:
#   Integral of T(t) where T(t) > 0 ºC: 16.00579441949021
#   Integral of |T(t)| where T(t) < 0 ºC: 20.51079345495649
# Year 8:
#   Integral of T(t) where T(t) > 0 ºC: 16.245305582228973
#   Integral of |T(t)| where T(t) < 0 ºC: 20.383831266178575
# Year 9:
#   Integral of T(t) where T(t) > 0 ºC: 16.485858591113885
#   Integral of |T(t)| where T(t) < 0 ºC: 20.25791138213891
# Year 10:
#   Integral of T(t) where T(t) > 0 ºC: 16.727445596933276
#   Integral of |T(t)| where T(t) < 0 ºC: 20.133025848229845
# Year 11:
#   Integral of T(t) where T(t) > 0 ºC: 16.970058860730685
#   Integral of |T(t)| where T(t) < 0 ºC: 20.009167032473542
# Year 12:
#   Integral of T(t) where T(t) > 0 ºC: 17.21369077003148
#   Integral of |T(t)| where T(t) < 0 ºC: 19.88632728713463
# Year 13:
#   Integral of T(t) where T(t) > 0 ºC: 17.458333784824887
#   Integral of |T(t)| where T(t) < 0 ºC: 19.76449913784212
# Year 14:
#   Integral of T(t) where T(t) > 0 ºC: 17.703980404136352
#   Integral of |T(t)| where T(t) < 0 ºC: 19.643674902197564
# Year 15:
#   Integral of T(t) where T(t) > 0 ºC: 17.95062339289039
#   Integral of |T(t)| where T(t) < 0 ºC: 19.523847529730293
# Year 16:
#   Integral of T(t) where T(t) > 0 ºC: 18.198255462065642
#   Integral of |T(t)| where T(t) < 0 ºC: 19.40500967249693
# Year 17:
#   Integral of T(t) where T(t) > 0 ºC: 18.446869471452732
#   Integral of |T(t)| where T(t) < 0 ºC: 19.287154192368423
# Year 18:
#   Integral of T(t) where T(t) > 0 ºC: 18.69645836663658
#   Integral of |T(t)| where T(t) < 0 ºC: 19.17027403339026
# Year 19:
#   Integral of T(t) where T(t) > 0 ºC: 18.947015179264017
#   Integral of |T(t)| where T(t) < 0 ºC: 19.05436223536919
# Year 20:
#   Integral of T(t) where T(t) > 0 ºC: 19.19853303231677
#   Integral of |T(t)| where T(t) < 0 ºC: 18.93941192652555
# Year 21:
#   Integral of T(t) where T(t) > 0 ºC: 19.451005124415673
#   Integral of |T(t)| where T(t) < 0 ºC: 18.82541629720312
# Year 22:
#   Integral of T(t) where T(t) > 0 ºC: 19.704424768908158
#   Integral of |T(t)| where T(t) < 0 ºC: 18.712368667469793
# Year 23:
#   Integral of T(t) where T(t) > 0 ºC: 19.958785305144417
#   Integral of |T(t)| where T(t) < 0 ºC: 18.600262378759933
# Year 24:
#   Integral of T(t) where T(t) > 0 ºC: 20.214080196325984
#   Integral of |T(t)| where T(t) < 0 ºC: 18.489090896368364
# Year 25:
#   Integral of T(t) where T(t) > 0 ºC: 20.47030300763439
#   Integral of |T(t)| where T(t) < 0 ºC: 18.378847788571083
# Year 26:
#   Integral of T(t) where T(t) > 0 ºC: 20.72744731588652
#   Integral of |T(t)| where T(t) < 0 ºC: 18.269526619149065
# Year 27:
#   Integral of T(t) where T(t) > 0 ºC: 20.985506787971666
#   Integral of |T(t)| where T(t) < 0 ºC: 18.161121110409116
# Year 28:
#   Integral of T(t) where T(t) > 0 ºC: 21.244475233543266
#   Integral of |T(t)| where T(t) < 0 ºC: 18.053624995177927
# Year 29:
#   Integral of T(t) where T(t) > 0 ºC: 21.50434647023134
#   Integral of |T(t)| where T(t) < 0 ºC: 17.947032146846425
# Year 30:
#   Integral of T(t) where T(t) > 0 ºC: 21.76511435701327
#   Integral of |T(t)| where T(t) < 0 ºC: 17.841336406924796
# Year 31:
#   Integral of T(t) where T(t) > 0 ºC: 22.02677290934496
#   Integral of |T(t)| where T(t) < 0 ºC: 17.736531810392773
# Year 32:
#   Integral of T(t) where T(t) > 0 ºC: 22.289316168219074
#   Integral of |T(t)| where T(t) < 0 ºC: 17.632612390046287
# Year 33:
#   Integral of T(t) where T(t) > 0 ºC: 22.552738242301483
#   Integral of |T(t)| where T(t) < 0 ºC: 17.529572240471268
# Year 34:
#   Integral of T(t) where T(t) > 0 ºC: 22.81703330864153
#   Integral of |T(t)| where T(t) < 0 ºC: 17.42740556491996
# Year 35:
#   Integral of T(t) where T(t) > 0 ºC: 23.08219561655335
#   Integral of |T(t)| where T(t) < 0 ºC: 17.326106600813898
# Year 36:
#   Integral of T(t) where T(t) > 0 ºC: 23.348219460773016
#   Integral of |T(t)| where T(t) < 0 ºC: 17.22566965821054
# Year 37:
#   Integral of T(t) where T(t) > 0 ºC: 23.615099214404776
#   Integral of |T(t)| where T(t) < 0 ºC: 17.126089100514818
# Year 38:
#   Integral of T(t) where T(t) > 0 ºC: 23.88282932790546
#   Integral of |T(t)| where T(t) < 0 ºC: 17.027359386380848
# Year 39:
#   Integral of T(t) where T(t) > 0 ºC: 24.15140427786621
#   Integral of |T(t)| where T(t) < 0 ºC: 16.929474987657475
# Year 40:
#   Integral of T(t) where T(t) > 0 ºC: 24.420818630562454
#   Integral of |T(t)| where T(t) < 0 ºC: 16.832430479106883
# Year 41:
#   Integral of T(t) where T(t) > 0 ºC: 24.691066961556572
#   Integral of |T(t)| where T(t) < 0 ºC: 16.73622043972351
# Year 42:
#   Integral of T(t) where T(t) > 0 ºC: 24.962144026402154
#   Integral of |T(t)| where T(t) < 0 ºC: 16.64083962215686
# Year 43:
#   Integral of T(t) where T(t) > 0 ºC: 25.234044480375264
#   Integral of |T(t)| where T(t) < 0 ºC: 16.54628268788501
# Year 44:
#   Integral of T(t) where T(t) > 0 ºC: 25.50676321316685
#   Integral of |T(t)| where T(t) < 0 ºC: 16.452544527752007
# Year 45:
#   Integral of T(t) where T(t) > 0 ºC: 25.78029482610099
#   Integral of |T(t)| where T(t) < 0 ºC: 16.359619742118003
# Year 46:
#   Integral of T(t) where T(t) > 0 ºC: 26.054634439584234
#   Integral of |T(t)| where T(t) < 0 ºC: 16.26750346109153
# Year 47:
#   Integral of T(t) where T(t) > 0 ºC: 26.32977694242886
#   Integral of |T(t)| where T(t) < 0 ºC: 16.176190569502918
# Year 48:
#   Integral of T(t) where T(t) > 0 ºC: 26.605717332676946
#   Integral of |T(t)| where T(t) < 0 ºC: 16.085676068537843
# Year 49:
#   Integral of T(t) where T(t) > 0 ºC: 26.882450663464613
#   Integral of |T(t)| where T(t) < 0 ºC: 15.995954999748637
# Year 50:
#   Integral of T(t) where T(t) > 0 ºC: 27.159971835030753
#   Integral of |T(t)| where T(t) < 0 ºC: 15.907022512200433
# Year 51:
#   Integral of T(t) where T(t) > 0 ºC: 27.438276592333743
#   Integral of |T(t)| where T(t) < 0 ºC: 15.818873730372754
# Year 52:
#   Integral of T(t) where T(t) > 0 ºC: 27.717355575179702
#   Integral of |T(t)| where T(t) < 0 ºC: 15.73149983591142
# Year 53:
#   Integral of T(t) where T(t) > 0 ºC: 27.99721625152336
#   Integral of |T(t)| where T(t) < 0 ºC: 15.644908177091398
# Year 54:
#   Integral of T(t) where T(t) > 0 ºC: 28.27784189620133
#   Integral of |T(t)| where T(t) < 0 ºC: 15.55908197958439
# Year 55:
#   Integral of T(t) where T(t) > 0 ºC: 28.559231816282836
#   Integral of |T(t)| where T(t) < 0 ºC: 15.474020629185485
# Year 56:
#   Integral of T(t) where T(t) > 0 ºC: 28.84138186215396
#   Integral of |T(t)| where T(t) < 0 ºC: 15.38971987493491
# Year 57:
#   Integral of T(t) where T(t) > 0 ºC: 29.124286323952855
#   Integral of |T(t)| where T(t) < 0 ºC: 15.306174110125164
# Year 58:
#   Integral of T(t) where T(t) > 0 ºC: 29.40794183940355
#   Integral of |T(t)| where T(t) < 0 ºC: 15.223379904794413
# Year 59:
#   Integral of T(t) where T(t) > 0 ºC: 29.6923435159178
#   Integral of |T(t)| where T(t) < 0 ºC: 15.141332392982465
# Year 60:
#   Integral of T(t) where T(t) > 0 ºC: 29.977486942851794
#   Integral of |T(t)| where T(t) < 0 ºC: 15.060027163184772
# Year 61:
#   Integral of T(t) where T(t) > 0 ºC: 30.26336788581842
#   Integral of |T(t)| where T(t) < 0 ºC: 14.979459982790825
# Year 62:
#   Integral of T(t) where T(t) > 0 ºC: 30.549980055776455
#   Integral of |T(t)| where T(t) < 0 ºC: 14.899624540488206
# Year 63:
#   Integral of T(t) where T(t) > 0 ºC: 30.837324626666664
#   Integral of |T(t)| where T(t) < 0 ºC: 14.82052209358869
# Year 64:
#   Integral of T(t) where T(t) > 0 ºC: 31.125391969448984
#   Integral of |T(t)| where T(t) < 0 ºC: 14.742142918298136
# Year 65:
#   Integral of T(t) where T(t) > 0 ºC: 31.414179624256168
#   Integral of |T(t)| where T(t) < 0 ºC: 14.664484631522324
# Year 66:
#   Integral of T(t) where T(t) > 0 ºC: 31.70368349295479
#   Integral of |T(t)| where T(t) < 0 ºC: 14.587543081537657
# Year 67:
#   Integral of T(t) where T(t) > 0 ºC: 31.99389952775247
#   Integral of |T(t)| where T(t) < 0 ºC: 14.511314253531404
# Year 68:
#   Integral of T(t) where T(t) > 0 ºC: 32.28482337981418
#   Integral of |T(t)| where T(t) < 0 ºC: 14.435793795054018
# Year 69:
#   Integral of T(t) where T(t) > 0 ºC: 32.57645128713851
#   Integral of |T(t)| where T(t) < 0 ºC: 14.360977941549844
# Year 70:
#   Integral of T(t) where T(t) > 0 ºC: 32.868779159334935
#   Integral of |T(t)| where T(t) < 0 ºC: 14.286862619084305
# Year 71:
#   Integral of T(t) where T(t) > 0 ºC: 33.16180322483229
#   Integral of |T(t)| where T(t) < 0 ºC: 14.213444027302392
# Year 72:
#   Integral of T(t) where T(t) > 0 ºC: 33.455519010125634
#   Integral of |T(t)| where T(t) < 0 ºC: 14.140717752900224
# Year 73:
#   Integral of T(t) where T(t) > 0 ºC: 33.74992322195498
#   Integral of |T(t)| where T(t) < 0 ºC: 14.068680412045891
# Year 74:
#   Integral of T(t) where T(t) > 0 ºC: 34.04501173736205
#   Integral of |T(t)| where T(t) < 0 ºC: 13.997328021700538
# Year 75:
#   Integral of T(t) where T(t) > 0 ºC: 34.3407807905402
#   Integral of |T(t)| where T(t) < 0 ºC: 13.926656762617867
# Year 76:
#   Integral of T(t) where T(t) > 0 ºC: 34.637226765600275
#   Integral of |T(t)| where T(t) < 0 ºC: 13.85666286649897
# Year 77:
#   Integral of T(t) where T(t) > 0 ºC: 34.93434575561062
#   Integral of |T(t)| where T(t) < 0 ºC: 13.787342629066298
# Year 78:
#   Integral of T(t) where T(t) > 0 ºC: 35.23213411583769
#   Integral of |T(t)| where T(t) < 0 ºC: 13.718692341853153
# Year 79:
#   Integral of T(t) where T(t) > 0 ºC: 35.53058820291886
#   Integral of |T(t)| where T(t) < 0 ºC: 13.650708356387288
# Year 80:
#   Integral of T(t) where T(t) > 0 ºC: 35.829704416244894
#   Integral of |T(t)| where T(t) < 0 ºC: 13.58338708106664
# Year 81:
#   Integral of T(t) where T(t) > 0 ºC: 36.12947909786233
#   Integral of |T(t)| where T(t) < 0 ºC: 13.516724859283377
# Year 82:
#   Integral of T(t) where T(t) > 0 ºC: 36.429908780781325
#   Integral of |T(t)| where T(t) < 0 ºC: 13.450718215869353
# Year 83:
#   Integral of T(t) where T(t) > 0 ºC: 36.73098990040232
#   Integral of |T(t)| where T(t) < 0 ºC: 13.38536362263258
# Year 84:
#   Integral of T(t) where T(t) > 0 ºC: 37.03271903291835
#   Integral of |T(t)| where T(t) < 0 ºC: 13.320657613887876
# Year 85:
#   Integral of T(t) where T(t) > 0 ºC: 37.33509264225229
#   Integral of |T(t)| where T(t) < 0 ºC: 13.256596693911526
# Year 86:
#   Integral of T(t) where T(t) > 0 ºC: 37.63810740673908
#   Integral of |T(t)| where T(t) < 0 ºC: 13.193177517872453
# Year 87:
#   Integral of T(t) where T(t) > 0 ºC: 37.941759906216554
#   Integral of |T(t)| where T(t) < 0 ºC: 13.130396678838256
# Year 88:
#   Integral of T(t) where T(t) > 0 ºC: 38.24604679984365
#   Integral of |T(t)| where T(t) < 0 ºC: 13.06825084578729
# Year 89:
#   Integral of T(t) where T(t) > 0 ºC: 38.55096493669511
#   Integral of |T(t)| where T(t) < 0 ºC: 13.006736856413484
# Year 90:
#   Integral of T(t) where T(t) > 0 ºC: 38.85651058377358
#   Integral of |T(t)| where T(t) < 0 ºC: 12.945850991458261
# Year 91:
#   Integral of T(t) where T(t) > 0 ºC: 39.16268097202291
#   Integral of |T(t)| where T(t) < 0 ºC: 12.88559047304536
# Year 92:
#   Integral of T(t) where T(t) > 0 ºC: 39.46947272389948
#   Integral of |T(t)| where T(t) < 0 ºC: 12.825951931003754
# Remaining Period:
#   Integral of T(t) where T(t) > 0 ºC: 39.77688263224557
#   Integral of |T(t)| where T(t) < 0 ºC: 9.072060893357742
